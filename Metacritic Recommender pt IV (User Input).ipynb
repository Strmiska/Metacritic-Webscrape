# %% [markdown]
# # Building in user inputs...
# I want to be able to have users feed in reviews of games that they like.

# %%
import numpy as np
import pandas as pd
import re

from scipy import sparse
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv('metacriticfortuning.csv', index_col='Unnamed: 0')

# %%
df[df['title'].str.contains('Counter-Strike: Global Offensive')]
# Out:
#         is_critic           reviewer_name  reviewer_score  \
# 484             1  LEVEL (Czech Republic)              90
# 2425            1                PC Gamer              84
# 7763            1                     IGN              80
# 10351           1                 GameSpy              80
# 11601           1                GameSpot              85
# 15767           1               Eurogamer              90
# 17119           0                sinadoom               8
# 19362           1            PC PowerPlay              80
# 21881           1                GameStar              84
# 23716           1                3DJuegos              77
# 25301           1                  Vandal              80
# 26429           1             Destructoid              95
# 27158           1                Games.cz              90
# 28837           1               games(TM)              90
# 29361           1          Multiplayer.it              88
# 30392           1              VideoGamer              90
# 31849           1           Edge Magazine              70
# 33818           1                Gamer.nl              85
# 34287           0                     AWG               9
# 35558           0                 Tagirix               9
# 36286           1             SpazioGames              90
# 36962           1                PC Games              85
# 37835           1                   G4 TV              80
# 40951           1             GameWatcher              90
# 43068           1             GamesRadar+              60
# 47067           1             Meristation              90
# 47639           1               CD-Action              85
# 48570           1             Everyeye.it              80
# 50346           1         Pelit (Finland)              84
# 52260           0               DelleAlpi              10
# ...           ...                     ...             ...
# 122261          0            anasjavaid95              10
# 122262          0                Candyman               9
# 122263          0                VeryGudi              10
# 122264          0                BL1774RD              10
# 122265          0              PixelMoney              10
# 122266          0            EnemyInbound               8
# 122271          0                  Sarcia               9
# 122272          0               hhyjtjtyj               6
# 122273          0           TheEyeszlader               5
# 122275          0                  FLAY3R               9
# 122276          0                coupgang               9
# 122277          0                   MarI0               7
# 122279          0           ArthurMLGXXXL               8
# 122280          0             MrMaloteARG               8
# 122283          0               Phasiverx               9
# 122284          0              danPgaming               7
# 122285          0               ElementKZ               9
# 122286          0               BabyRants               5
# 122289          0                 Molodoi               0
# 122291          0               Mr_Bryant              10
# 122292          0                  RahulB               7
# 122293          0               DanIsSexy               8
# 122294          0                Shutdown               7
# 122295          0                 RUSKAIN               8
# 122296          0                Brooksey               7
# 122297          0                 tellgam               8
# 122301          0          This_username_               8
# 122304          0                    Anxo               8
# 122309          0               Gratee664               5
# 122310          0           deni_chakalov               9
#
#                                     url  \
# 484     counter-strike-global-offensive
# 2425    counter-strike-global-offensive
# 7763    counter-strike-global-offensive
# 10351   counter-strike-global-offensive
# 11601   counter-strike-global-offensive
# 15767   counter-strike-global-offensive
# 17119   counter-strike-global-offensive
# 19362   counter-strike-global-offensive
# 21881   counter-strike-global-offensive
# 23716   counter-strike-global-offensive
# 25301   counter-strike-global-offensive
# 26429   counter-strike-global-offensive
# 27158   counter-strike-global-offensive
# 28837   counter-strike-global-offensive
# 29361   counter-strike-global-offensive
# 30392   counter-strike-global-offensive
# 31849   counter-strike-global-offensive
# 33818   counter-strike-global-offensive
# 34287   counter-strike-global-offensive
# 35558   counter-strike-global-offensive
# 36286   counter-strike-global-offensive
# 36962   counter-strike-global-offensive
# 37835   counter-strike-global-offensive
# 40951   counter-strike-global-offensive
# 43068   counter-strike-global-offensive
# 47067   counter-strike-global-offensive
# 47639   counter-strike-global-offensive
# 48570   counter-strike-global-offensive
# 50346   counter-strike-global-offensive
# 52260   counter-strike-global-offensive
# ...                                 ...
# 122261  counter-strike-global-offensive
# 122262  counter-strike-global-offensive
# 122263  counter-strike-global-offensive
# 122264  counter-strike-global-offensive
# 122265  counter-strike-global-offensive
# 122266  counter-strike-global-offensive
# 122271  counter-strike-global-offensive
# 122272  counter-strike-global-offensive
# 122273  counter-strike-global-offensive
# 122275  counter-strike-global-offensive
# 122276  counter-strike-global-offensive
# 122277  counter-strike-global-offensive
# 122279  counter-strike-global-offensive
# 122280  counter-strike-global-offensive
# 122283  counter-strike-global-offensive
# 122284  counter-strike-global-offensive
# 122285  counter-strike-global-offensive
# 122286  counter-strike-global-offensive
# 122289  counter-strike-global-offensive
# 122291  counter-strike-global-offensive
# 122292  counter-strike-global-offensive
# 122293  counter-strike-global-offensive
# 122294  counter-strike-global-offensive
# 122295  counter-strike-global-offensive
# 122296  counter-strike-global-offensive
# 122297  counter-strike-global-offensive
# 122301  counter-strike-global-offensive
# 122304  counter-strike-global-offensive
# 122309  counter-strike-global-offensive
# 122310  counter-strike-global-offensive
#
#                                         title  norm_score  \
# 484     Counter-Strike: Global Offensive (PC)           9
# 2425    Counter-Strike: Global Offensive (PC)           8
# 7763    Counter-Strike: Global Offensive (PC)           8
# 10351   Counter-Strike: Global Offensive (PC)           8
# 11601   Counter-Strike: Global Offensive (PC)           9
# 15767   Counter-Strike: Global Offensive (PC)           9
# 17119   Counter-Strike: Global Offensive (PC)           8
# 19362   Counter-Strike: Global Offensive (PC)           8
# 21881   Counter-Strike: Global Offensive (PC)           8
# 23716   Counter-Strike: Global Offensive (PC)           8
# 25301   Counter-Strike: Global Offensive (PC)           8
# 26429   Counter-Strike: Global Offensive (PC)          10
# 27158   Counter-Strike: Global Offensive (PC)           9
# 28837   Counter-Strike: Global Offensive (PC)           9
# 29361   Counter-Strike: Global Offensive (PC)           9
# 30392   Counter-Strike: Global Offensive (PC)           9
# 31849   Counter-Strike: Global Offensive (PC)           7
# 33818   Counter-Strike: Global Offensive (PC)           9
# 34287   Counter-Strike: Global Offensive (PC)           9
# 35558   Counter-Strike: Global Offensive (PC)           9
# 36286   Counter-Strike: Global Offensive (PC)           9
# 36962   Counter-Strike: Global Offensive (PC)           9
# 37835   Counter-Strike: Global Offensive (PC)           8
# 40951   Counter-Strike: Global Offensive (PC)           9
# 43068   Counter-Strike: Global Offensive (PC)           6
# 47067   Counter-Strike: Global Offensive (PC)           9
# 47639   Counter-Strike: Global Offensive (PC)           9
# 48570   Counter-Strike: Global Offensive (PC)           8
# 50346   Counter-Strike: Global Offensive (PC)           8
# 52260   Counter-Strike: Global Offensive (PC)          10
# ...                                       ...         ...
# 122261  Counter-Strike: Global Offensive (PC)          10
# 122262  Counter-Strike: Global Offensive (PC)           9
# 122263  Counter-Strike: Global Offensive (PC)          10
# 122264  Counter-Strike: Global Offensive (PC)          10
# 122265  Counter-Strike: Global Offensive (PC)          10
# 122266  Counter-Strike: Global Offensive (PC)           8
# 122271  Counter-Strike: Global Offensive (PC)           9
# 122272  Counter-Strike: Global Offensive (PC)           6
# 122273  Counter-Strike: Global Offensive (PC)           5
# 122275  Counter-Strike: Global Offensive (PC)           9
# 122276  Counter-Strike: Global Offensive (PC)           9
# 122277  Counter-Strike: Global Offensive (PC)           7
# 122279  Counter-Strike: Global Offensive (PC)           8
# 122280  Counter-Strike: Global Offensive (PC)           8
# 122283  Counter-Strike: Global Offensive (PC)           9
# 122284  Counter-Strike: Global Offensive (PC)           7
# 122285  Counter-Strike: Global Offensive (PC)           9
# 122286  Counter-Strike: Global Offensive (PC)           5
# 122289  Counter-Strike: Global Offensive (PC)           0
# 122291  Counter-Strike: Global Offensive (PC)          10
# 122292  Counter-Strike: Global Offensive (PC)           7
# 122293  Counter-Strike: Global Offensive (PC)           8
# 122294  Counter-Strike: Global Offensive (PC)           7
# 122295  Counter-Strike: Global Offensive (PC)           8
# 122296  Counter-Strike: Global Offensive (PC)           7
# 122297  Counter-Strike: Global Offensive (PC)           8
# 122301  Counter-Strike: Global Offensive (PC)           8
# 122304  Counter-Strike: Global Offensive (PC)           8
# 122309  Counter-Strike: Global Offensive (PC)           5
# 122310  Counter-Strike: Global Offensive (PC)           9
#
#                                                     genre  reviewer_id
# 484     Action, Shooter, First-Person, Modern, Tactica...            1
# 2425    Action, Shooter, First-Person, Modern, Tactica...            4
# 7763    Action, Shooter, First-Person, Modern, Tactica...           34
# 10351   Action, Shooter, First-Person, Modern, Tactica...           36
# 11601   Action, Shooter, First-Person, Modern, Tactica...           37
# 15767   Action, Shooter, First-Person, Modern, Tactica...           41
# 17119   Action, Shooter, First-Person, Modern, Tactica...           43
# 19362   Action, Shooter, First-Person, Modern, Tactica...           57
# 21881   Action, Shooter, First-Person, Modern, Tactica...           61
# 23716   Action, Shooter, First-Person, Modern, Tactica...           63
# 25301   Action, Shooter, First-Person, Modern, Tactica...           79
# 26429   Action, Shooter, First-Person, Modern, Tactica...           81
# 27158   Action, Shooter, First-Person, Modern, Tactica...           82
# 28837   Action, Shooter, First-Person, Modern, Tactica...           86
# 29361   Action, Shooter, First-Person, Modern, Tactica...           87
# 30392   Action, Shooter, First-Person, Modern, Tactica...           88
# 31849   Action, Shooter, First-Person, Modern, Tactica...           92
# 33818   Action, Shooter, First-Person, Modern, Tactica...           98
# 34287   Action, Shooter, First-Person, Modern, Tactica...           99
# 35558   Action, Shooter, First-Person, Modern, Tactica...          121
# 36286   Action, Shooter, First-Person, Modern, Tactica...          142
# 36962   Action, Shooter, First-Person, Modern, Tactica...          143
# 37835   Action, Shooter, First-Person, Modern, Tactica...          146
# 40951   Action, Shooter, First-Person, Modern, Tactica...          158
# 43068   Action, Shooter, First-Person, Modern, Tactica...          162
# 47067   Action, Shooter, First-Person, Modern, Tactica...          187
# 47639   Action, Shooter, First-Person, Modern, Tactica...          188
# 48570   Action, Shooter, First-Person, Modern, Tactica...          189
# 50346   Action, Shooter, First-Person, Modern, Tactica...          196
# 52260   Action, Shooter, First-Person, Modern, Tactica...          211
# ...                                                   ...          ...
# 122261  Action, Shooter, First-Person, Modern, Tactica...        14937
# 122262  Action, Shooter, First-Person, Modern, Tactica...        14938
# 122263  Action, Shooter, First-Person, Modern, Tactica...        14939
# 122264  Action, Shooter, First-Person, Modern, Tactica...        14940
# 122265  Action, Shooter, First-Person, Modern, Tactica...        14941
# 122266  Action, Shooter, First-Person, Modern, Tactica...        14942
# 122271  Action, Shooter, First-Person, Modern, Tactica...        14943
# 122272  Action, Shooter, First-Person, Modern, Tactica...        14944
# 122273  Action, Shooter, First-Person, Modern, Tactica...        14945
# 122275  Action, Shooter, First-Person, Modern, Tactica...        14946
# 122276  Action, Shooter, First-Person, Modern, Tactica...        14947
# 122277  Action, Shooter, First-Person, Modern, Tactica...        14948
# 122279  Action, Shooter, First-Person, Modern, Tactica...        14949
# 122280  Action, Shooter, First-Person, Modern, Tactica...        14950
# 122283  Action, Shooter, First-Person, Modern, Tactica...        14951
# 122284  Action, Shooter, First-Person, Modern, Tactica...        14952
# 122285  Action, Shooter, First-Person, Modern, Tactica...        14953
# 122286  Action, Shooter, First-Person, Modern, Tactica...        14954
# 122289  Action, Shooter, First-Person, Modern, Tactica...        14955
# 122291  Action, Shooter, First-Person, Modern, Tactica...        14956
# 122292  Action, Shooter, First-Person, Modern, Tactica...        14957
# 122293  Action, Shooter, First-Person, Modern, Tactica...        14958
# 122294  Action, Shooter, First-Person, Modern, Tactica...        14959
# 122295  Action, Shooter, First-Person, Modern, Tactica...        14960
# 122296  Action, Shooter, First-Person, Modern, Tactica...        14961
# 122297  Action, Shooter, First-Person, Modern, Tactica...        14962
# 122301  Action, Shooter, First-Person, Modern, Tactica...        14963
# 122304  Action, Shooter, First-Person, Modern, Tactica...        14964
# 122309  Action, Shooter, First-Person, Modern, Tactica...        14965
# 122310  Action, Shooter, First-Person, Modern, Tactica...        14966
#
# [411 rows x 8 columns]

# %%
df.shape
# Out:
# (221303, 8)

# %% [markdown]
# # User input will be added to the DF and then picked for recommendations...
# Currently the input will be accepted into the dataframe and then ran through the same filters as before. We want to make sure we keep only relevant information, so technically it will be possible to throw errors if we wanted to.

# %%
# Get the user's name
name = str(raw_input("Please enter your name: "))

gametitle = [] # empty lists to hold the user's review titles and scores
gamescore = []

exit = False

# I will run this loop to collect games and reviews until the user is finished
while exit == False:
    
    results = []

    gamesearch = str(raw_input("Please enter a title to review: "))
    
    while len(results) > 1 or len(results) == 0:
        results = []

        for title in df['title'].unique():
            if re.search(gamesearch, title, re.IGNORECASE):
                results.append(title) #gather up the possible results...
        count = 0
        if len(results) > 1:
            for i in results:
                print "[" + str(count) + "]" + " | " + i
                count += 1
            gamenumber = int(raw_input("There are multiple results. Please chose a number: "))
            results = [results[gamenumber]]
        elif len(results) == 0:
            gamesearch = str(raw_input("You returned nothing, try again: "))
        else:
            break

    gametitle.append(results[0])
    print "You've selected: " + gametitle[-1]
    print
    
    # Get the user's score for the game
    loop = True
    while loop == True:
        score = int(raw_input("Please give the title a score from 0-10: "))
        if score >= 0 and score <=10:
            gamescore.append(score)
            loop = False
        else:
            loop = True
    
    # Ask if the users wants to stop adding games
    loop = True
    while loop == True:
        confirm = str(raw_input("Would you like to add another game? (y/n): "))
        if confirm == 'y' or confirm =='Y':
            exit = False
            loop = False
        elif confirm == 'n' or confirm =='N':
            exit = True
            loop = False
        else:
            loop = True
# Out:
# Please enter your name: Keith Strmiska
# Please enter a title to review: Doom
# [0] | Deponia Doomsday (PC)
# [1] | Doom 3 BFG Edition (PC)
# [2] | DOOM (PC)
# [3] | Doom 3 (PC)
# [4] | Doom 3: Resurrection of Evil (PC)
# [5] | Doom II (PC)
# [6] | Hearts of Iron II: Doomsday (PC)
# [7] | Hector: Badge of Carnage - Episode 3: Beyond Reasonable Doom (PC)
# There are multiple results. Please chose a number: 2
# You've selected: DOOM (PC)
#
# Please give the title a score from 0-10: 10
# Would you like to add another game? (y/n): y
# Please enter a title to review: call of duty
# [0] | Call of Duty: Black Ops (PC)
# [1] | Call of Duty: Modern Warfare 2 (PC)
# [2] | Call of Duty: Modern Warfare 3 (PC)
# [3] | Call of Duty: World at War (PC)
# [4] | Call of Duty: Advanced Warfare (PC)
# [5] | Call of Duty: Black Ops II (PC)
# [6] | Call of Duty: Black Ops III (PC)
# [7] | Call of Duty: Ghosts (PC)
# [8] | Call of Duty: Infinite Warfare (PC)
# [9] | Call of Duty (PC)
# [10] | Call of Duty 2 (PC)
# [11] | Call of Duty 4: Modern Warfare (PC)
# [12] | Call of Duty: United Offensive (PC)
# [13] | Call of Duty: Modern Warfare Remastered (PC)
# There are multiple results. Please chose a number: 2
# You've selected: Call of Duty: Modern Warfare 3 (PC)
#
# Please give the title a score from 0-10: 7
# Would you like to add another game? (y/n): y
# Please enter a title to review: league of legends
# You've selected: League of Legends (PC)
#
# Please give the title a score from 0-10: 8
# Would you like to add another game? (y/n): y
# Please enter a title to review: dota 2
# You've selected: Dota 2 (PC)
#
# Please give the title a score from 0-10: 8
# Would you like to add another game? (y/n): y
# Please enter a title to review: heroes of the storm
# You've selected: Heroes of the Storm (PC)
#
# Please give the title a score from 0-10: 9
# Would you like to add another game? (y/n): n

# %%
# The gathered information from the user as variables... (name, game titles, game scores)
print name
print gametitle
print gamescore
# Out:
# Keith Strmiska
# ['DOOM (PC)', 'Call of Duty: Modern Warfare 3 (PC)', 'League of Legends (PC)', 'Dota 2 (PC)', 'Heroes of the Storm (PC)']
# [10, 7, 8, 8, 9]

# %%
# Build the variables into a dictionary 'entry' for each game
# Each dictionary is fed into the 'reviewedlist' as a list of dictionaries...

reviewedlist = []
for g,s in zip(gametitle, gamescore):
    entry = {}
    entry['is_critic'] = 0
    entry['reviewer_name'] = name
    entry['reviewer_score'] = s
    entry['url'] = 'user'
    entry['title'] = g
    entry['norm_score'] = s
    entry['genre'] = 'user'
    entry['reviewer_id'] = -1
    
    reviewedlist.append(entry)

# %%
# convert the list of dictionaries to a dataframe and append it to the primary dataframe

userdf = pd.DataFrame(reviewedlist)
df = df.append(userdf)
df.tail(10)
# Out:
#                                                   genre  is_critic  \
# 221298  Strategy, Tycoon, Management, Business / Tycoon          0
# 221299  Strategy, Tycoon, Management, Business / Tycoon          0
# 221300  Strategy, Tycoon, Management, Business / Tycoon          0
# 221301            Miscellaneous, Puzzle, Action, Action          0
# 221302            Miscellaneous, Puzzle, Action, Action          0
# 0                                                  user          0
# 1                                                  user          0
# 2                                                  user          0
# 3                                                  user          0
# 4                                                  user          0
#
#         norm_score  reviewer_id   reviewer_name  reviewer_score  \
# 221298           8        85366        K.Lawson               8
# 221299           9        85367            TyR.               9
# 221300           7        85368          BethS.               7
# 221301           8        85369        HenrikW.               8
# 221302           4        85370      conradhall               4
# 0               10           -1  Keith Strmiska              10
# 1                7           -1  Keith Strmiska               7
# 2                8           -1  Keith Strmiska               8
# 3                8           -1  Keith Strmiska               8
# 4                9           -1  Keith Strmiska               9
#
#                                       title             url
# 221298                    Zoo Tycoon 2 (PC)    zoo-tycoon-2
# 221299                    Zoo Tycoon 2 (PC)    zoo-tycoon-2
# 221300                    Zoo Tycoon 2 (PC)    zoo-tycoon-2
# 221301                 Zuma's Revenge! (PC)  zumas-revenge!
# 221302                 Zuma's Revenge! (PC)  zumas-revenge!
# 0                                 DOOM (PC)            user
# 1       Call of Duty: Modern Warfare 3 (PC)            user
# 2                    League of Legends (PC)            user
# 3                               Dota 2 (PC)            user
# 4                  Heroes of the Storm (PC)            user

# %% [markdown]
# ## Create a column called 'Avg Score' which is the average score of the user

# %%
avg_df = df.groupby(['reviewer_name']).median().reset_index()
avg_df = avg_df.drop(['is_critic', 'reviewer_score', 'reviewer_id'], axis=1)
avg_df = avg_df.rename(columns={'norm_score': 'avg_score'})
df = pd.merge(df, avg_df, on='reviewer_name')

# %% [markdown]
# ## Filter out reviewers with a median score less than 3

# %%
df = df[df['avg_score'].values > 3]

# %% [markdown]
# ## We only want to keep users with 4 or more reviews

# %%
df = df.groupby('reviewer_id').filter(lambda x: len(x) > 3)

# %%
#New Dataset has an average of almost 20 reviews per person!
print "average reviews per person:"
print np.mean(df.reviewer_id.value_counts())
print
#New Dataset has 121437 reviews...
print "length of dataframe:"
print len(df)
print

print "top reviewers:"
print df.reviewer_id.value_counts()[:10]
# Out:
# average reviews per person:
# 19.6813614263
#
# length of dataframe:
# 121434
#
# top reviewers:
# 37     2446
# 34     2417
# 4      2308
# 30     1365
# 87     1130
# 36     1109
# 1      1027
# 61     1025
# 40      965
# 188     954
# Name: reviewer_id, dtype: int64

# %%
df.head()
# Out:
#                                            genre  is_critic  norm_score  \
# 0  Action, Shooter, First-Person, Modern, Arcade          1           4
# 1  Action, Shooter, First-Person, Modern, Arcade          1           4
# 2  Action, Shooter, First-Person, Modern, Arcade          1           4
# 3            Adventure, General, Point-and-Click          1           8
# 4            Adventure, General, Point-and-Click          1           8
#
#    reviewer_id reviewer_name  reviewer_score             title          url  \
# 0            0      GamingXP              35  007 Legends (PC)  007-legends
# 1            0      GamingXP              35  007 Legends (PC)  007-legends
# 2            0      GamingXP              35  007 Legends (PC)  007-legends
# 3            0      GamingXP              81      15 Days (PC)      15-days
# 4            0      GamingXP              81      15 Days (PC)      15-days
#
#    avg_score
# 0        8.0
# 1        8.0
# 2        8.0
# 3        8.0
# 4        8.0

# %% [markdown]
# ## Need to fix the index and reviewer_id since they are now missing values...
# We also need to do this to set the new added user into the dataframe without any repeats happening

# %%
df = df.reset_index()
df = df.drop(['index'], axis=1)

# %%
df.head()
# Out:
#                                            genre  is_critic  norm_score  \
# 0  Action, Shooter, First-Person, Modern, Arcade          1           4
# 1  Action, Shooter, First-Person, Modern, Arcade          1           4
# 2  Action, Shooter, First-Person, Modern, Arcade          1           4
# 3            Adventure, General, Point-and-Click          1           8
# 4            Adventure, General, Point-and-Click          1           8
#
#    reviewer_id reviewer_name  reviewer_score             title          url  \
# 0            0      GamingXP              35  007 Legends (PC)  007-legends
# 1            0      GamingXP              35  007 Legends (PC)  007-legends
# 2            0      GamingXP              35  007 Legends (PC)  007-legends
# 3            0      GamingXP              81      15 Days (PC)      15-days
# 4            0      GamingXP              81      15 Days (PC)      15-days
#
#    avg_score
# 0        8.0
# 1        8.0
# 2        8.0
# 3        8.0
# 4        8.0

# %% [markdown]
# ### Building a new reviewer_id

# %%
#Build a df to make a new reviewer_id so we don't have any empty spaces...
revName = pd.DataFrame(df['reviewer_name'].unique())

revName.columns = ['reviewer_name']
revName['reviewer_id_fixt'] = range(len(revName))

# %%
revName.head()
# Out:
#             reviewer_name  reviewer_id_fixt
# 0                GamingXP                 0
# 1  LEVEL (Czech Republic)                 1
# 2      PC Master (Greece)                 2
# 3             Riot Pixels                 3
# 4                PC Gamer                 4

# %%
revName.tail()
# Out:
#         reviewer_name  reviewer_id_fixt
# 6165           Andrea              6165
# 6166  skulltulainahat              6166
# 6167             mose              6167
# 6168     Dallaswithad              6168
# 6169   Keith Strmiska              6169

# %%
# Merge the new list to the DF, drop and rename the old reviewer id column.
df = pd.merge(df, revName, on='reviewer_name')
df = df.drop(['reviewer_id'], axis=1)
df = df.rename(columns={'reviewer_id_fixt': 'reviewer_id'})

# %%
df.head(10)
# Out:
#                                                genre  is_critic  norm_score  \
# 0      Action, Shooter, First-Person, Modern, Arcade          1           4
# 1      Action, Shooter, First-Person, Modern, Arcade          1           4
# 2      Action, Shooter, First-Person, Modern, Arcade          1           4
# 3                Adventure, General, Point-and-Click          1           8
# 4                Adventure, General, Point-and-Click          1           8
# 5                Adventure, General, Point-and-Click          1           8
# 6  Strategy, Real-Time, General, Historic, Fantas...          1           7
# 7                        Adventure, General, General          1           9
# 8                 Action, Simulation, Flight, Combat          1           8
# 9             Strategy, Turn-Based, Wargame, General          1           8
#
#   reviewer_name  reviewer_score  \
# 0      GamingXP              35
# 1      GamingXP              35
# 2      GamingXP              35
# 3      GamingXP              81
# 4      GamingXP              81
# 5      GamingXP              81
# 6      GamingXP              72
# 7      GamingXP              85
# 8      GamingXP              80
# 9      GamingXP              75
#
#                                                title  \
# 0                                   007 Legends (PC)
# 1                                   007 Legends (PC)
# 2                                   007 Legends (PC)
# 3                                       15 Days (PC)
# 4                                       15 Days (PC)
# 5                                       15 Days (PC)
# 6                    A Game of Thrones: Genesis (PC)
# 7                    A New Beginning: Final Cut (PC)
# 8  Ace Combat Assault Horizon: Enhanced Edition (PC)
# 9                  Achtung Panzer: Kharkov 1943 (PC)
#
#                                            url  avg_score  reviewer_id
# 0                                  007-legends        8.0            0
# 1                                  007-legends        8.0            0
# 2                                  007-legends        8.0            0
# 3                                      15-days        8.0            0
# 4                                      15-days        8.0            0
# 5                                      15-days        8.0            0
# 6                    a-game-of-thrones-genesis        8.0            0
# 7                    a-new-beginning-final-cut        8.0            0
# 8  ace-combat-assault-horizon-enhanced-edition        8.0            0
# 9                  achtung-panzer-kharkov-1943        8.0            0

# %% [markdown]
# ## Looking up the recently added User
# We'll use the variable we created earlier called 'name' to look up our recently added user and their reviews.

# %%
# Hello person!

df[df['reviewer_name'].str.contains(name)]
# Out:
#        genre  is_critic  norm_score   reviewer_name  reviewer_score  \
# 121429  user          0          10  Keith Strmiska              10
# 121430  user          0           7  Keith Strmiska               7
# 121431  user          0           8  Keith Strmiska               8
# 121432  user          0           8  Keith Strmiska               8
# 121433  user          0           9  Keith Strmiska               9
#
#                                       title   url  avg_score  reviewer_id
# 121429                            DOOM (PC)  user        8.0         6169
# 121430  Call of Duty: Modern Warfare 3 (PC)  user        8.0         6169
# 121431               League of Legends (PC)  user        8.0         6169
# 121432                          Dota 2 (PC)  user        8.0         6169
# 121433             Heroes of the Storm (PC)  user        8.0         6169

# %%
# Find the reviewer_id where the reviewer_name is == our name variable as make sure it is an int type.

nameIndex = int(df['reviewer_id'].where(df['reviewer_name'] == name).unique()[-1])

# %% [markdown]
# # Setting up a pivot table

# %%
pivot = df.pivot_table(index='reviewer_id', columns='title', values='norm_score')
pivot.shape
# Out:
# (6170, 4457)

# %%
pivot.fillna(0).values
pivot.shape
# Out:
# (6170, 4457)

# %%
pivot.head()
# Out:
# title        007 Legends (PC)  007: NightFire (PC)  \
# reviewer_id
# 0                         4.0                  NaN
# 1                         3.0                  NaN
# 2                         3.0                  NaN
# 3                         3.0                  NaN
# 4                         2.0                  6.0
#
# title        007: Quantum of Solace (PC)  0RBITALIS (PC)  \
# reviewer_id
# 0                                    NaN             NaN
# 1                                    6.0             NaN
# 2                                    NaN             NaN
# 3                                    NaN             NaN
# 4                                    NaN             NaN
#
# title        10 Second Ninja (PC)  10,000,000 (PC)  1001 Spikes (PC)  \
# reviewer_id
# 0                             NaN              NaN               NaN
# 1                             NaN              NaN               NaN
# 2                             NaN              NaN               NaN
# 3                             NaN              5.0               NaN
# 4                             NaN              NaN               NaN
#
# title        12 is Better Than 6 (PC)  140 (PC)  15 Days (PC)  \
# reviewer_id
# 0                                 NaN       NaN           8.0
# 1                                 NaN       NaN           6.0
# 2                                 NaN       NaN           NaN
# 3                                 NaN       NaN           NaN
# 4                                 NaN       NaN           NaN
#
# title                      ...                 Zoo Tycoon: Marine Mania (PC)  \
# reviewer_id                ...
# 0                          ...                                           NaN
# 1                          ...                                           NaN
# 2                          ...                                           NaN
# 3                          ...                                           NaN
# 4                          ...                                           NaN
#
# title        Zuma's Revenge! (PC)  continue?9876543210 (PC)  iRacing (PC)  \
# reviewer_id
# 0                             6.0                       NaN           NaN
# 1                             NaN                       NaN           NaN
# 2                             NaN                       NaN           NaN
# 3                             NaN                       NaN           NaN
# 4                             6.0                       NaN           NaN
#
# title        imprint-X (PC)  inMomentum (PC)  kill.switch (PC)  nail'd (PC)  \
# reviewer_id
# 0                       NaN              NaN               NaN          7.0
# 1                       NaN              5.0               NaN          6.0
# 2                       NaN              NaN               NaN          NaN
# 3                       NaN              NaN               NaN          NaN
# 4                       NaN              NaN               7.0          8.0
#
# title        rymdkapsel (PC)  theHunter: Call of the Wild (PC)
# reviewer_id
# 0                        NaN                               NaN
# 1                        8.0                               NaN
# 2                        NaN                               NaN
# 3                        NaN                               NaN
# 4                        NaN                               6.0
#
# [5 rows x 4457 columns]

# %% [markdown]
# # Building a sparse matrix

# %%
pivotsparse = sparse.csc_matrix(pivot.fillna(0).values)

# %%
pivot.fillna(0).shape
# Out:
# (6170, 4457)

# %% [markdown]
# ## Running the Model

# %%
# I put the pivotsparse in NearestNeighbors and checked the for the closest neighbors around user_id (watevs).

X = pivotsparse
nbrs = NearestNeighbors(n_neighbors=7).fit(X) #6
distances, indices = nbrs.kneighbors(pivotsparse[nameIndex]) #We put latest users 'nameIndex' in the sparse index


# The most similar users in the dataframe
print distances
print "-"*20
print indices
# Out:
# [[  0.          18.          18.08314132  18.27566688  18.52025918
#    18.70828693  18.70828693]]
# --------------------
# [[6169 3485 2153 4188 2574 5268 4801]]

# %% [markdown]
# ## OUTPUT

# %%
# Set the reviewer and closest related reviewers to variables from the indicies of the kneighbors output
sample_reviewer = indices[0][0]
suggested_reviewers = indices[0][1:]

print sample_reviewer
print suggested_reviewers
# Out:
# 6169
# [3485 2153 4188 2574 5268 4801]

# %%
# Make a function to filter out titles that our user has played...

def user_suggestions(ur, sr):
    usrTitles = []
    for t in pivot.iloc[ur].dropna().index:
        usrTitles.append(t)
    sugTitles = []
    for rec in sr:
        for t in pivot.iloc[rec].dropna().index:
            sugTitles.append(t)

    recommendations = [x for x in sugTitles if x not in usrTitles]

    return recommendations

# %%
print 'Hello ' + name + "."
print
print 'Here are your Reviews:'
print "-"*60
print pivot.iloc[sample_reviewer].dropna().sort_values(ascending=False)
print
print "*"*60
print "Here are a few recommendations from similar gamers!"
print "*"*60
print
for i in user_suggestions(sample_reviewer, suggested_reviewers):
    
    # Returning the titles that have a 50% average score or higher...
    if df['norm_score'].where(df['title'] == i).mean() >= 5.0:
        print i
# Out:
# Hello Keith Strmiska.
#
# Here are your Reviews:
# ------------------------------------------------------------
# title
# DOOM (PC)                              10.0
# Heroes of the Storm (PC)                9.0
# League of Legends (PC)                  8.0
# Dota 2 (PC)                             8.0
# Call of Duty: Modern Warfare 3 (PC)     7.0
# Name: 6169, dtype: float64
#
# ************************************************************
# Here are a few recommendations from similar gamers!
# ************************************************************
#
# Binary Domain (PC)
# Crysis 2 (PC)
# The Elder Scrolls V: Skyrim (PC)
# Call of Duty: Advanced Warfare (PC)
# Diablo III: Reaper of Souls (PC)
# Fallout 4 (PC)
# BioShock Infinite (PC)
# Grand Theft Auto IV (PC)
# Battlefield 3 (PC)
# Rage (PC)
# Fallout 4 (PC)
# Hearts of Iron IV (PC)
# The Elder Scrolls V: Skyrim (PC)
# Deadfall Adventures (PC)
# Narcosis (PC)
# Thief (PC)
